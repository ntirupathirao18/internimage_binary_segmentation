# %%
import torch
print(torch.__version__)
print(torch.version.cuda)
# Out:
# 2.0.0+cu118
# 11.8

# %%
# !pip install mmcv-full==1.5.0 -f https://download.openmmlab.com/mmcv/dist/cu118/torch2.0/index.html
# !pip install timm==0.6.11 mmdet==2.28.1
# !pip install opencv-python termcolor yacs pyyaml scipy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Looking in links: https://download.openmmlab.com/mmcv/dist/cu118/torch2.0/index.html
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 530.8/530.8 kB 14.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 200.9/200.9 kB 21.0 MB/s eta 0:00:00
# ...
#   Created wheel for mmcv-full: filename=mmcv_full-1.5.0-cp310-cp310-linux_x86_64.whl size=31355320 sha256=5e0687725b2c704b226e2dfb9864ab380941ef362a8384c260940b0592febcc3
#   Stored in directory: /root/.cache/pip/wheels/04/60/cf/301dac4d1de6b0583122bf09fe71a47ff9627d7f3837219cc9
# Successfully built mmcv-full
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 548.7/548.7 kB 14.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 63.9 MB/s eta 0:00:00
# ...

# %%
# !git clone https://github.com/ntirupathirao18/internimage_binary_segmentation.git
# !cd internimage_binary_segmentation
# Out:
# fatal: destination path 'internimage_binary_segmentation' already exists and is not an empty directory.

# %%
# !cd /content/internimage_binary_segmentation/segmentation/ops_dcnv3

# %%
# !python /content/internimage_binary_segmentation/segmentation/ops_dcnv3/setup.py build install
# Out:
# running build
# running build_ext
# /usr/local/lib/python3.10/dist-packages/torch/utils/cpp_extension.py:476: UserWarning: Attempted to use ninja as the BuildExtension backend but we could not find ninja.. Falling back to using the slow distutils backend.
#   warnings.warn(msg.format('we could not find ninja.'))
# /usr/local/lib/python3.10/dist-packages/torch/utils/cpp_extension.py:398: UserWarning: There are no x86_64-linux-gnu-g++ version bounds defined for CUDA version 11.8
#   warnings.warn(f'There are no {compiler_name} version bounds defined for CUDA version {cuda_str_version}')
# building 'DCNv3' extension
# creating build
# creating build/temp.linux-x86_64-cpython-310
# creating build/temp.linux-x86_64-cpython-310/content
# creating build/temp.linux-x86_64-cpython-310/content/internimage_binary_segmentation
# creating build/temp.linux-x86_64-cpython-310/content/internimage_binary_segmentation/segmentation
# ...

# %%
# !cd internimage_binary_segmentation

# %%
from shutil import copytree
copytree('/content/dist', '/content/InternImage/segmentation/ops_dcnv3/dist')
copytree('/content/build', '/content/internimage_binary_segmentation/segmentation/ops_dcnv3/build')
# Out:
# '/content/internimage_binary_segmentation/segmentation/ops_dcnv3/build'

# %%
#!pip install openmim
# !pip install mmsegmentation==0.27.0
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 817.6/817.6 kB 20.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 648.8/648.8 kB 58.0 MB/s eta 0:00:00
# ...

# %%
# !python /content/internimage_binary_segmentation/segmentation/train.py
# Out:
# Traceback (most recent call last):
#   File "/content/internimage_binary_segmentation/segmentation/train.py", line 14, in <module>
#     import mmcv
# ModuleNotFoundError: No module named 'mmcv'

# %%
# !python /content/internimage_binary_segmentation/segmentation/train.py /content/internimage_binary_segmentation/segmentation/configs/ade20k/upernet_internimage_b_512_160k_ade20k.py
# Out:
# Traceback (most recent call last):
#   File "/content/internimage_binary_segmentation/segmentation/train.py", line 14, in <module>
#     import mmcv
# ModuleNotFoundError: No module named 'mmcv'

# %%
# !pip install -q kaggle
from google.colab import files
files.upload()
# !mkdir ~/.kaggle
! cp kaggle.json ~/.kaggle/
! chmod 600 ~/.kaggle/kaggle.json
! kaggle datasets list
# Out:
#      <input type="file" id="files-ab49535b-3b7e-4939-9d24-693a57d6951b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ab49535b-3b7e-4939-9d24-693a57d6951b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !kaggle datasets download -d vbookshelf/pneumothorax-chest-xray-images-and-masks
# Out:
# ...
# 100% 4.48G/4.50G [00:31<00:00, 68.5MB/s]
# 100% 4.50G/4.50G [00:31<00:00, 154MB/s]

# %%
! mkdir data
! unzip pneumothorax-chest-xray-images-and-masks.zip -d data

# %%
import pandas as pd
import shutil
import os
def filter_data(csv_path, input_path, type_run) :
  df = pd.read_csv(csv_path)
  imageids_list = df['new_filename'].tolist()
  folders_names = ['image','mask']
  for indfolder in folders_names :
    if not os.path.exists(os.path.join(input_path,type_run, indfolder)) :
      os.makedirs(os.path.join(input_path, type_run,indfolder))
  for indid in imageids_list :
    shutil.copy(os.path.join(input_path, 'png_images', indid), os.path.join(input_path,type_run, 'image', indid))
    shutil.copy(os.path.join(input_path, 'png_masks', indid), os.path.join(input_path,type_run, 'mask', indid))

filter_data(r'/content/data/siim-acr-pneumothorax/stage_1_train_images.csv', r'/content/data/siim-acr-pneumothorax' , type_run = 'train')
filter_data(r'/content/data/siim-acr-pneumothorax/stage_1_test_images.csv', r'/content/data/siim-acr-pneumothorax' ,  type_run = 'test')

# %%
import pandas as pd
import shutil
import os
import cv2
from matplotlib import pyplot as plt
import numpy as np
def filter_data_v2(csv_path, input_path, type_run) :
  df = pd.read_csv(csv_path)
  imageids_list = df['new_filename'].tolist()
  folders_names = ['image','mask']
  for indfolder in folders_names :
    if not os.path.exists(os.path.join(input_path,type_run, indfolder)) :
      os.makedirs(os.path.join(input_path, type_run,indfolder))
  for indid in imageids_list :
    shutil.copy(os.path.join(input_path, 'png_images', indid), os.path.join(input_path,type_run, 'image', indid))
    
    mask = cv2.imread(os.path.join(input_path, 'png_masks', indid))
    b_mask = np.copy(mask)
    #d = (('[255,255,255]':[1,1,1]))
    #for old, new in d.items():
    b_mask[mask == [255,255,255]] = 200
    # b_mask[mask == [0, 0, 0]] = 0
    b_mask = cv2.cvtColor(b_mask, cv2.COLOR_BGR2GRAY)

    cv2.imwrite(os.path.join(input_path,type_run, 'mask', indid) , b_mask)
     

filter_data_v2(r'/content/data/siim-acr-pneumothorax/stage_1_train_images.csv', r'/content/data/siim-acr-pneumothorax' , type_run = 'train_v2')
filter_data_v2(r'/content/data/siim-acr-pneumothorax/stage_1_test_images.csv', r'/content/data/siim-acr-pneumothorax' ,  type_run = 'test_v2')

# %%
import pandas as pd
import shutil
import os
import cv2
from matplotlib import pyplot as plt
import numpy as np
import glob 
def filter_mask_v2(input_path ) :
  path_lists = glob.glob(input_path+'/*.*')
  if not os.path.exists(os.path.join(r'/content/data/data/data','masks_class_v3')) :
      os.makedirs(os.path.join(r'/content/data/data/data','masks_class_v3'))
  for indpath in path_lists :
    mask = cv2.imread(indpath)
    b_mask = np.copy(mask)
    # #d = (('[255,255,255]':[1,1,1]))
    # #for old, new in d.items():
    b_mask[mask == [128,128,128]] = 1
    # # b_mask[mask == [0, 0, 0]] = 0
    # b_mask = cv2.cvtColor(b_mask, cv2.COLOR_BGR2GRAY)
    
    cv2.imwrite(indpath.replace('masks','masks_class_v3') , b_mask )
     

filter_mask_v2(r'/content/data/data/data/masks')

# %%
# !kaggle datasets download -d fakhrealam9537/leaf-disease-segmentation-dataset
! mkdir data
! unzip leaf-disease-segmentation-dataset.zip -d data

# %%
# !python /content/internimage_binary_segmentation/segmentation/train.py /content/internimage_binary_segmentation/custom_config_leaf.py

# %%
# Out:
# array([128, 128, 128, ..., 128, 128, 128], dtype=uint8)

# %%
# !python /content/internimage_binary_segmentation/segmentation/train.py /content/internimage_binary_segmentation/custom_config.py
# Out:
# 2023-05-18 19:27:57,956 - mmseg - INFO - Multi-processing start method is `None`
# 2023-05-18 19:27:57,956 - mmseg - INFO - OpenCV num_threads is `2
# fatal: not a git repository (or any of the parent directories): .git
# 2023-05-18 19:27:57,977 - mmseg - INFO - Environment info:
# ------------------------------------------------------------
# sys.platform: linux
# Python: 3.10.11 (main, Apr  5 2023, 14:15:10) [GCC 9.4.0]
# CUDA available: True
# GPU 0: Tesla T4
# CUDA_HOME: /usr/local/cuda
# NVCC: Cuda compilation tools, release 11.8, V11.8.89
# GCC: x86_64-linux-gnu-gcc (Ubuntu 9.4.0-1ubuntu1~20.04.1) 9.4.0
# PyTorch: 2.0.0+cu118
# PyTorch compiling details: PyTorch built with:
#   - GCC 9.3
#   - C++ Version: 201703
#   - Intel(R) oneAPI Math Kernel Library Version 2022.2-Product Build 20220804 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v2.7.3 (Git Hash 6dbeffbae1f23cbbeae17adb7b5b13f1f37c080e)
#   - OpenMP 201511 (a.k.a. OpenMP 4.5)
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# <ipython-input-17-d5df0069828e> in <cell line: 2>()
#       1 from google.colab import drive
# ----> 2 drive.mount('/content/drive')
#
# /usr/local/lib/python3.10/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#     101 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#     102   """Mount your Google Drive at the specified mountpoint path."""
# --> 103   return _mount(
#     104       mountpoint,
#     105       force_remount=force_remount,
#
# /usr/local/lib/python3.10/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     130   )
#     131   if ephemeral:
# --> 132     _message.blocking_request(
#     133         'request_auth', request={'authType': 'dfs_ephemeral'}, timeout_sec=None
# ...

# %%
from mmseg.apis import init_model, inference_model, show_result_pyplot

config_path = 'configs/pspnet/pspnet_r50-d8_4xb2-40k_cityscapes-512x1024.py'
checkpoint_path = 'checkpoints/pspnet_r50-d8_512x1024_40k_cityscapes_20200605_003338-2966598c.pth'
img_path = 'demo/demo.png'


# build the model from a config file and a checkpoint file
model = init_model(config_path, checkpoint_path, device='cuda:0')

# inference on given image
result = inference_model(model, img_path)

# display the segmentation result
vis_image = show_result_pyplot(model, img_path, result)

# %%
import shutil
shutil.copy_tree(r'/content/data/data/data')
